# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose the Search Performance Optimization lane because the dataset contains search-performance metrics such as search volume, impressions, clicks, sessions, and measurable opportunity. My goal is to use these data to identify which content should be prioritized for optimization. This project focuses on supporting content and SEO decisions rather than simply training a machine learning model.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Decision**
#
# Which content pages should be prioritized for optimization based on historical search-performance data?
#
# **Unit of analysis**
#
# One content page.
#
# **Output**
#
# A ranked list or priority score indicating which pages should be reviewed first.
#
# **Action**
#
# A content or SEO team can improve titles, content quality, internal links, or keyword targeting for the highest-priority pages.
#
# **Cost of a wrong recommendation**
#
# If low-impact pages are selected, time and resources may be spent on pages that provide little benefit while higher-value opportunities are missed.
#
# **Why Data/ML can help**
#
# The dataset contains thousands of content pages and many features. Data analysis and machine learning can identify patterns that help prioritize optimization efforts more consistently than manual review alone.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/processed/refresh_feature_vector.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nContent Types:")
print(df["content_type"].value_counts())

print("\nSearch Intent:")
print(df["main_intent"].value_counts())

print("\nMeasurable Opportunity:")
print(df["measurable_opportunity"].value_counts())
# Out:
# Rows: 30000
# Columns: 52
#
# Content Types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64
#
# Search Intent:
# main_intent
# informational    17235
# transactional     5733
# commercial        4612
# unknown           2374
# navigational        46
# Name: count, dtype: int64
#
# Measurable Opportunity:
# measurable_opportunity
# 1    22006
# 0     7994
# Name: count, dtype: int64

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains **30,000 rows** and **52 columns**, providing a substantial amount of information for analysis.
#
# The dataset includes search-related features such as search volume, competition, CPC, impressions, clicks, sessions, trend direction, and measurable opportunity.
#
# The distribution of content types, search intent, and measurable opportunities indicates that the dataset contains meaningful variation, making it suitable for prioritizing content optimization decisions.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project can identify observed patterns in historical search-performance data and provide decision-support for prioritizing content optimization.
#
# The findings are directional and based on the available dataset. They should not be interpreted as proof that a specific optimization will increase traffic or rankings.
#
# This project cannot establish causal relationships, predict Google's search algorithm, or guarantee future search performance.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
